# %%
import NNMFit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import matplotlib.font_manager as font_manager
font_axis_label = {'family': 'serif',
        'color':  'black',
        'weight': 'normal',
        'size': 22,
        }
font_title = {'family': 'serif',
        'color':  'black',
        'weight': 'bold',
        'size': 20,
        }
font_legend = font_manager.FontProperties(family='serif',
                                   weight='normal',
                                   style='normal', size=13)

plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams.update({'font.family':'serif'})

# %%
fit_res_dir_dict = {
                 "track_SAY" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/output/data_Tracks_SAY.pickle",
                 "cscd_SAY" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/output/data_Cscd_SAY.pickle",
                 "track_cscd_nohybrid_SAY" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/output/data_Tracks_Cscd_nohybrid_SAY.pickle",
                 "track_cscd_SAY" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/output/data_Tracks_Cscd_SAY.pickle",

                 "track_SAY_he_nominal" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/output/data_Tracks_SAY_he_nominal.pickle",
                 "track_cscd_nohybrid_SAY_he_nominal" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/output/data_Tracks_Cscd_nohybrid_SAY_he_nominal_local.pickle",
                 }

# %%
pickles = {}

for name, pickle_file_path in fit_res_dir_dict.items():
    print(name)
    pickles[name] = pd.read_pickle(pickle_file_path)
    print( "norm", pickles[name]["fit-result"][1]["astro_norm"],
           "gamma",pickles[name]["fit-result"][1]["gamma_astro"],
           "chi2", pickles[name]["fit-result"][0] )
# Out:
# track_SAY
# norm 1.748063675275883 gamma 2.4396809047605923 chi2 4205.564784941955
# cscd_SAY
# norm 1.5953697373885176 gamma 2.585008753288956 chi2 240.43153732662867
# track_cscd_nohybrid_SAY
# norm 1.7755788207862448 gamma 2.526882998487011 chi2 4407.293163061194
# track_cscd_SAY
# norm 1.8669074110142572 gamma 2.5116981298688543 chi2 4459.4666720180985
# track_SAY_he_nominal
# norm 1.7049517411676396 gamma 2.3946196920922462 chi2 4218.334595170369
# track_cscd_nohybrid_SAY_he_nominal
# norm 1.795645668927821 gamma 2.5174099004674426 chi2 4420.721910363263

# %%
scan_dir_dict = {
                ### new neha method
                 "track_neha" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/SAY/track_bestfit_neha",
                 "track_cscd_neha" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/SAY/track_cscd_nohybrid_bestfit_neha",

                 "track_he_nominal_neha" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/SAY/track_he_nominal_bestfit_neha",
                 "track_cscd_he_nominal_neha" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/SAY/track_cscd_he_nominal_nohybrid_bestfit_neha",
                 }

# %%
models_dir_dict = {

                ### spl
                 "track_SPL" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/SPL/track",
                 "track_cscd_SPL" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/SPL/track_cscd",

                 "track_he_nominal_SPL" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/SPL/track_he_nominal",
                 "track_cscd_he_nominal_SPL" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/SPL/track_cscd_he_nominal",

                 ### bpl
                 "track_brokenPL" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/brokenPL/track",
                 "track_cscd_brokenPL" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/brokenPL/track_cscd",

                 "track_he_nominal_brokenPL" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/brokenPL/track_he_nominal",
                 "track_cscd_he_nominal_brokenPL" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/brokenPL/track_cscd_he_nominal",

                 ### two component
                 "track_two_component" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/two_component/track",
                 "track_cscd_two_component" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/two_component/track_cscd",

                 "track_he_nominal_two_component" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/two_component/track_he_nominal",
                 "track_cscd_he_nominal_two_component" : "/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/create_dag/output/models/two_component/track_cscd_he_nominal",


}

# %%
drop_unsuccessful = True

scan_dict = {}

x = {}
y = {}
dllh = {}

bestfits = {}

for name, scan_dir in scan_dir_dict.items():
    print(name)
    # use force_read if new scan points are produced
    scan_dict[name] = NNMFit.utilities.ScanHandler(scan_dir,dump=False,drop_unsuccessful=drop_unsuccessful)
    x[name], y[name], dllh[name] = scan_dict[name].get_scan_xydllh(x="astro_norm",y="gamma_astro",interpolate=True, drop_unsuccessful=drop_unsuccessful)

    bestfits[name] = scan_dict[name].get_freefit(drop_unsuccessful="True")


for name, scan_dir in models_dir_dict.items():
    print(name)
    # use force_read if new scan points are produced
    scan_dict[name] = NNMFit.utilities.ScanHandler(scan_dir,dump=False,drop_unsuccessful=drop_unsuccessful)

    bestfits[name] = scan_dict[name].get_freefit(drop_unsuccessful="True")
# Out:
# track_neha
# track_cscd_neha
# track_he_nominal_neha
# track_cscd_he_nominal_neha
# track_SPL
# track_cscd_SPL
# track_he_nominal_SPL
# track_cscd_he_nominal_SPL
# track_brokenPL
# track_cscd_brokenPL
# track_he_nominal_brokenPL
# track_cscd_he_nominal_brokenPL
# track_two_component
# track_cscd_two_component
# track_he_nominal_two_component
# track_cscd_he_nominal_two_component

# %%
# compare my single fit, to other scan fit attempts
print("Track")
print("One manual fit, norm:", pickles["track_SAY"]["fit-result"][1]["astro_norm"], "gamma:", pickles["track_SAY"]["fit-result"][1]["gamma_astro"] )
print("Neha, norm: ", bestfits["track_neha"]['astro_norm'], "gamma:",  bestfits["track_neha"]['gamma_astro'])
print("SPL, norm: ", bestfits["track_SPL"]['astro_norm'], "gamma:",  bestfits["track_SPL"]['gamma_astro'])

print("Track+Cscd")
print("One manual fit, norm:", pickles["track_cscd_nohybrid_SAY"]["fit-result"][1]["astro_norm"], "gamma:", pickles["track_cscd_nohybrid_SAY"]["fit-result"][1]["gamma_astro"] )
print("Neha, norm: ", bestfits["track_cscd_neha"]['astro_norm'], "gamma:",  bestfits["track_cscd_neha"]['gamma_astro'])
print("SPL, norm: ", bestfits["track_cscd_SPL"]['astro_norm'], "gamma:",  bestfits["track_cscd_SPL"]['gamma_astro'])

print("Track+he_nominal")
print("One manual fit, norm:", pickles["track_SAY_he_nominal"]["fit-result"][1]["astro_norm"], "gamma:", pickles["track_SAY_he_nominal"]["fit-result"][1]["gamma_astro"] )
print("Neha, norm: ", bestfits["track_he_nominal_neha"]['astro_norm'], "gamma:",  bestfits["track_he_nominal_neha"]['gamma_astro'])
print("SPL, norm: ", bestfits["track_he_nominal_SPL"]['astro_norm'], "gamma:",  bestfits["track_he_nominal_SPL"]['gamma_astro'])

print("Track+Cscd+he_nominal")
print("One manual fit, norm:", pickles["track_cscd_nohybrid_SAY_he_nominal"]["fit-result"][1]["astro_norm"], "gamma:", pickles["track_cscd_nohybrid_SAY_he_nominal"]["fit-result"][1]["gamma_astro"] )
print("Neha, norm: ", bestfits["track_cscd_he_nominal_neha"]['astro_norm'], "gamma:",  bestfits["track_cscd_he_nominal_neha"]['gamma_astro'])
print("SPL, norm: ", bestfits["track_cscd_he_nominal_SPL"]['astro_norm'], "gamma:",  bestfits["track_cscd_he_nominal_SPL"]['gamma_astro'])
# Out:
# Track
# One manual fit, norm: 1.748063675275883 gamma: 2.4396809047605923
# Neha, norm:  1.7480204989265895 gamma: 2.439670179964053
# SPL, norm:  1.7480206156166525 gamma: 2.4396712646350203
# Track+Cscd
# One manual fit, norm: 1.7755788207862448 gamma: 2.526882998487011
# Neha, norm:  1.7755709268903626 gamma: 2.5268827423763836
# SPL, norm:  1.775571615793404 gamma: 2.526884653222733
# Track+he_nominal
# One manual fit, norm: 1.7049517411676396 gamma: 2.3946196920922462
# Neha, norm:  1.7050028632538319 gamma: 2.394633744976055
# SPL, norm:  1.704992224501939 gamma: 2.394634211667693
# Track+Cscd+he_nominal
# One manual fit, norm: 1.795645668927821 gamma: 2.5174099004674426
# Neha, norm:  1.7954734993132424 gamma: 2.5174017652708978
# SPL, norm:  1.7955062654559841 gamma: 2.517405485737326

# %%
from scipy.interpolate import interp1d
from scipy.optimize import root_scalar

root_1_sigma = 1.0

def find_errors( name ):

    print(5*"-", name)

    parameters = scan_dict[name].get_scan_list()

    for parameter in parameters:

        if parameter == "freefit": continue

        print(parameter)

        # best fit
        print("bestfit", bestfits[name][parameter])

        scan = scan_dict[name].get_scan_df( param_name = parameter, drop_unsuccessful = drop_unsuccessful)
        
        # if parameter == "gamma_astro":
        #     print(scan[parameter], scan["dllh"])

        interpolator_dllh = interp1d(scan[parameter], scan["dllh"], kind='linear', fill_value="extrapolate")

        # Define a function to find the points where dllh = 0.5
        def find_root(value):
            return lambda x: interpolator_dllh(x) - value

        # Solve for points where dllh = 0.5
        roots = []
        for initial_guess in np.linspace(scan[parameter].min(), scan[parameter].max(), 100):
            # print(initial_guess, interpolator_dllh(initial_guess))
            try:
                sol = root_scalar(find_root(root_1_sigma), bracket=[initial_guess, initial_guess + 0.1], method='bisect')
                if sol.converged:
                    roots.append(sol.root)
            except ValueError:
                continue  # Skip intervals where there are no solutions

        # print(roots)

        # Remove duplicate roots that are very close to each other
        threshold = 1e-2  # Define a distance threshold
        unique_roots = []
        for root in roots:
            if not unique_roots or all(abs(root - ur) > threshold for ur in unique_roots):
                unique_roots.append(root)
            
        print(unique_roots)


for name in models_dir_dict:
    find_errors(name)
# find_errors("track_cscd_SPL")
# Out:
# ----- track_SPL
# astro_norm
# bestfit 1.7480206156166525
# [1.3670086134094164, 2.0197330751977396]
# gamma_astro
# bestfit 2.4396712646350203
# [2.3534292585319503, 2.5082678693376526]
# ----- track_cscd_SPL
# astro_norm
# bestfit 1.775571615793404
# [1.6105112285306065, 1.9467049179723186]
# gamma_astro
# bestfit 2.526884653222733
# [2.5429407153561545, 2.5588383792638947]
# ----- track_he_nominal_SPL
# astro_norm
# bestfit 1.704992224501939
# [1.987639910437304]
# gamma_astro
# bestfit 2.394634211667693
# [2.287369412276644, 2.4692382501062706]
# ----- track_cscd_he_nominal_SPL
# astro_norm
# bestfit 1.7955062654559841
# [1.626790225813874, 1.9696610260136145]
# gamma_astro
# bestfit 2.517405485737326
# []
# ----- track_brokenPL
# astro_norm
# bestfit 1.7480410343688098
# [1.3670085112637027, 2.0197330750376685]
# e_break
# bestfit 7.999999999998022
# [5.759431088016677, 6.953748767254619]
# gamma_1
# bestfit 2.4396790215907322
# ...

# %%
def plot_dllh( name, parameter ):

    scan = scan_dict[name].get_scan_df( param_name = parameter, drop_unsuccessful = drop_unsuccessful)

    fig, (ax) = plt.subplots(1, 1)

    ax.plot( scan[parameter], scan["dllh"] )
    ax.axhline(0.5, color="red", linestyle="--", label="dllh = 0.5")

    ax.set_xlabel(parameter)
    ax.set_ylabel("dllh")
    ax.legend()

    plt.savefig(f"/data/user/tvaneede/GlobalFit/analysis/combined_track_shower/plots/output/dllh/dllh_name-{name}_parameter-{parameter}.pdf")

# for name in models_dir_dict:
#     parameters = scan_dict[name].get_scan_list()
#     for parameter in parameters:
#         if parameter == "freefit": continue
#         plot_dllh( name, parameter )

# %%
# compare chi2
-2*(bestfits["track_cscd_SPL"].llh-bestfits["track_cscd_brokenPL"].llh)
# Out:
# -5.292508821537922
